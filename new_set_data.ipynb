# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dpath = "/content/drive/MyDrive/contest/Git_Contest/data/"

# %%
public = pd.read_csv (dpath+'전국공공체육시설데이터.csv')

# %%
public.head()
# Out:
#            FACI_NM FACI_GB_CD FACI_GB_NM FCOB_CD FCOB_NM FTYPE_CD FTYPE_NM  \
# 0          (외립석입구)          P         공공     P08   간이운동장    P0801    간이운동장
# 1          (자산경로당)          P         공공     P08   간이운동장    P0801    간이운동장
# 2  신리 봉계초등학교 (강당뒤)          P         공공     P08   간이운동장    P0801    간이운동장
# 3  신리 봉계초등학교 (강당뒤)          P         공공     P08   간이운동장    P0801    간이운동장
# 4              성당뒤          P         공공     P08   간이운동장    P0801    간이운동장
#
#    FMNG_TYPE_GB_CD FMNG_TYPE_GB_NM    FMNG_CP_CD  ... FMNG_CPB_NM  \
# 0              1.0          지방자치단체  4.700000e+09  ...         김천시
# 1              1.0          지방자치단체  4.700000e+09  ...         김천시
# 2              1.0          지방자치단체  4.700000e+09  ...         김천시
# 3              1.0          지방자치단체  4.700000e+09  ...         김천시
# 4              1.0          지방자치단체  4.700000e+09  ...         김천시
#
#      ADDR_CP_CD ADDR_CP_NM   ADDR_CPB_CD ADDR_CPB_NM  FACI_POINT_X  \
# ...

# %%
public.info() # null값이 많은 컬럼순으로 결측치를 처리해볼까? 일단 ADDR_AMD_CD, ADDR_AMD_NM 이 두 변수는 모든 값이 null이라 컬럼 삭제할게
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31138 entries, 0 to 31137
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FACI_NM            31138 non-null  object
#  1   FACI_GB_CD         31138 non-null  object
#  2   FACI_GB_NM         31138 non-null  object
#  3   FCOB_CD            31138 non-null  object
#  4   FCOB_NM            31138 non-null  object
#  5   FTYPE_CD           31138 non-null  object
#  6   FTYPE_NM           31138 non-null  object
#  7   FMNG_TYPE_GB_CD    30673 non-null  float64
#  8   FMNG_TYPE_GB_NM    30673 non-null  object
#  9   FMNG_CP_CD         31128 non-null  float64
#  10  FMNG_CP_NM         31128 non-null  object
#  11  FMNG_CPB_CD        31128 non-null  float64
#  12  FMNG_CPB_NM        31128 non-null  object
#  13  FMNG_DEPT_NM       12632 non-null  object
#  14  FMNG_USER_TEL      12323 non-null  object
#  15  ADDR_CP_CD         31137 non-null  float64
# ...

# %%
public = public.drop(['ADDR_AMD_CD', 'ADDR_AMD_NM'], axis=1)

# %%
public = public.drop(['STAND_CPT_PSN_CNT', 'STAND_SEAT_CNT'], axis=1) # 수용인원, 관람석도 무의미해서 삭제

# %%
public = public.drop(['TOT_FACI_AREA', 'FACI_HOMEPAGE','FMNG_DEPT_NM','FMNG_USER_TEL'], axis=1) # 시설면적(㎡), 홈페이지, 담당자 부서, 담당자 연락처도 자료수 적고 무의미해서 삭제

# %% [markdown]
# ADDR_EMD_CD 도로명 동읍면코드
# ADDR_EMD_NM 도로명 동읍면명
# FACI_ROAD_ADDR1 도로명 주소
# 이 변수들은 이렇게까지 자세한 주소가 필요할까 싶어서 삭제해도 될듯? null값도 많기도하고..

# %%
public = public.drop(['ADDR_EMD_CD', 'ADDR_EMD_NM','FACI_ROAD_ADDR1'], axis=1)

# %%
city_list = public.drop_duplicates(['FMNG_CPB_NM'])['FMNG_CPB_NM'] # 어떤 도시 있는지 볼라고 중복 제거 후 따로 변수에 저장

# %%
city_list # 시군구 총 221개가 있네용... 시군구 별로 소유한 체육시설 파악 못하겠는데 ? 너무많다. 도별로 줄여서 먼저 분석할까 아님 그냥 서울시로 줄여버릴까 ..?
# Out:
# 0         김천시
# 5         문경시
# 7         산청군
# 11        연천군
# 12        광산구
#          ...
# 11485     의왕시
# 13854    전라북도
# 14265    전라남도
# 14517    동대문구
# 19993    충청북도
# Name: FMNG_CPB_NM, Length: 221, dtype: object

# %%
a = public.sort_values(by=['FMNG_CP_NM'])   #  ['FMNG_CP_NM'].value_counts()

# %%
a['FMNG_CP_NM'].value_counts() #도별 시설 갯수
# Out:
# 경상북도       6678
# 경기도        4729
# 전라남도       3040
# 경상남도       2901
# 충청북도       2406
# 강원도        2277
# 서울특별시      1585
# 충청남도       1344
# 부산광역시      1151
# 전라북도       1026
# 인천광역시       946
# 대구광역시       862
# 광주광역시       764
# 대전광역시       547
# 제주특별자치도     470
# 울산광역시       329
# 세종특별자치시      73
# Name: FMNG_CP_NM, dtype: int64
